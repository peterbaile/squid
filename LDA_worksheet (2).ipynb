# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk) (1.15.0)

# %%
import pandas as pd
from datetime import datetime
import numpy as np

# %%
df_read = pd.read_csv("/content/drive/My Drive/Analytics Spring 2020/Work Streams/Core DS/Content Rec/DP Data/dp.csv")

# %%
sample=df_read.sort_values(by=['published_date'])
sample = sample.drop_duplicates()
df = sample.dropna()
df['date'] = pd.to_datetime(df['published_date'])
df1 = df[df.date > datetime.strptime("2009","%Y")]
df1
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#        Unnamed: 0      id  ...       published_date                date
# 30680       30825  121752  ...  2009-01-14 10:00:00 2009-01-14 10:00:00
# 30679       30824  121753  ...  2009-01-14 10:00:00 2009-01-14 10:00:00
# 30678       30823  121754  ...  2009-01-14 10:00:00 2009-01-14 10:00:00
# 30677       30822  121734  ...  2009-01-14 10:00:00 2009-01-14 10:00:00
# 30676       30821  121756  ...  2009-01-14 10:00:00 2009-01-14 10:00:00
# ...           ...     ...  ...                  ...                 ...
# 85192         204  190843  ...  2020-07-31 04:03:10 2020-07-31 04:03:10
# 85191         203  190851  ...  2020-07-31 04:30:46 2020-07-31 04:30:46
# 85190         202  190854  ...  2020-07-31 05:09:18 2020-07-31 05:09:18
# 85189         201  190856  ...  2020-07-31 08:33:29 2020-07-31 08:33:29
# 85188         200  190855  ...  2020-07-31 13:11:27 2020-07-31 13:11:27
#
# [31477 rows x 9 columns]

# %%
sample_data = df1
import re
sample_data['content_p'] = sample_data['content'].astype(str)
sample_data['content_p'] = sample_data['content_p'].map(lambda x: x.lower())

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('english')
pat = r'\b(?:{})\b'.format('|'.join(stop))
sample_data['content_p'] = sample_data['content_p'].str.replace(pat, '')
sample_data['content_p'] = sample_data['content_p'].str.replace(r'\s+', ' ')
sample_data['content_p'] = sample_data['content_p'].map(lambda x: re.sub('[,\.!?’‘]', '', x))

import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
lemmatizer=WordNetLemmatizer()
remove_list = ['amp', 'http', '19']
def subLemma(word):
  return lemmatizer.lemmatize(word) #lemmatize
  #find_result = list(map(word.find, remove_list))

  #if (sum(find_result) > -1 * len(find_result)):
    #return ''
  #else:
    #return word  
def lemma (input_str):
  input_str=word_tokenize(input_str)
  input_str = list(map(subLemma, input_str))
  return ' '.join(input_str)
  
lemma('G20 leaders agreed #coronaviru combating pandemic calls transparent robust coordinated large-scale science-based global response spirit solidarity ')

sample_data['content_p'] = sample_data['content_p'].apply(lambda x: lemma(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sample_data['content_p'] = sample_data['content_p'].apply(lambda x: re.sub(r'\d+', '', x))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
# Helper function
def plot_40_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[:40]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 
    
    plt.figure(2, figsize=(15, 15/1.6180))
    plt.subplot(title='40 most common words')
    sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})
    sns.barplot(x_pos, counts, palette='husl')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.show()
    return count_dict
# Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer(stop_words='english', max_df=0.1, min_df=0.001)
# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(sample_data['content_p'])

# Visualise the 10 most common words
count_dict = plot_40_most_common_words(count_data, count_vectorizer)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#function to print lda and top documents

import warnings
warnings.simplefilter("ignore", DeprecationWarning)
# Load the LDA model from sk-learn
from sklearn.decomposition import LatentDirichletAllocation as LDA
documents = sample_data['title'].tolist() 
# Helper function
def print_topics(model, count_vectorizer, n_top_words, no_top_documents, no_chars, count_data):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        W = model.transform(count_data)
       
        top_doc_indices = np.argsort( W[:,topic_idx] )[::-1][0:no_top_documents]
        for doc_index in top_doc_indices:
          print(doc_index)
          print (documents[doc_index])

# %%
number_topics = 20
number_words = 20
number_documents = 10
# Create and fit the LDA model
random_number = np.random.random()
print(random_number)
lda = LDA(n_components=number_topics, n_jobs=-1, random_state=42)
lda.fit(count_data)

# %% [markdown]
# #  LDA Topics And Articles

# %%
print_topics(lda, count_vectorizer, number_words, number_documents, 150, count_data)
# Out:
# Topic #0:
# reported suspect block male unaffiliated st theft female arrested unknown bike walnut removed located man police 45 oct vehicle spruce
# 2261
# Crime Log
# 6982
# Crime log: March 26 - April 7
# 5280
# Crime log: Oct. 22-28
# 7865
# Crime log: Sept. 23-29
# 17044
# Crime Log: Oct. 24 – Oct. 30
# 9091
# Crime Log | Jan. 27 - Feb. 2
# 5001
# Crime log: Sept. 24-30
# 2317
# Crime Log
# 5495
# Crime log: Nov. 5-11
# 7779
# Crime log: Sept. 16-22
#
# Topic #1:
# yard football quarterback touchdown offense bagnoli running quarter defensive receiver offensive priore drive watson dartmouth ragone pas wagner wide rushing
# 19812
# Penn football one win away from title after win over Harvard
# 29857
# Five takeaways from Penn football's thrilling win over Brown
# 25369
# Last-second goal-line stand boosts Penn football to wild win over Cornell in season finale
# 24839
# Penn sprint football falls to Army in a heavyweight battle, 24-14
# 19024
# Taking a look at Penn football's nonconference matchups
# 16479
# Heartbreak city: Penn football falls in season opener to Jacksonville, 34-31
# 19792
# Penn football preps for clash with Harvard with title on line
# 29468
# Penn football falls to No. 20 Delaware, 28-27, in nail-biting season opener
# 25203
# Homecoming heroics secure Penn football a thrilling late 38-35 victory over rival Princeton
# 25177
# Penn football gears up for Homecoming showdown against archnemesis Princeton
#
# Topic #2:
# championship race competition relay track finish finished athlete meter runner invitational compete ncaa cross swimming schnur dolan 200 fencing squad
# 26845
# With Olympic legends in attendance, Quakers shine in 124th edition of Penn Relays
# 10212
# Nine Quakers set to compete at NCAA Championships
# 20890
# Men's swimming's Chris Swanson becomes Penn's first ever national champion in 1650
# 16015
# NCAA Finals highlight season of track and field success
# 15979
# Three Quakers qualify for NCAA finals in Track and Field
# 28905
# Penn men's and women's track post impressive performances at three different meets
# 23548
# Penn track and field seeks to pull off an upset at the Ivy League Championships
# 26194
# Penn women's track and field wins first Ivy League indoor championship in 22 years; men take second
# 20587
# Penn men's swimming set for Ivy Championships
# 20837
# Track & Field Issue | Pair of local meets highlight start of outdoor season
#
# Topic #3:
# medical mental medicine patient care cap hospital cancer nursing researcher disease information treatment drug data resource app death doctor suicide
# 5361
# Penn Med researchers report new tumor-shrinking technology
# 9143
# Penn Med finds new vaccine for breast cancer
# 25859
# CAPS looks to address 'growing demand' for services with University review of operations
# 21480
# Human trial using gene that slows aging approved at Penn Medicine
# 12939
# Penn Medicine technology facilitates rare mutation detection
# 4940
# Penn Med tests heart valve procedure
# 4314
# Prof. begins development of blood test for appendicitis
# 28974
# Penn Med researchers use CRISPR technology to treat lung disease in mice
# 3587
# Study finds a link between brain diseases
# 30501
# Penn Med finds patients more likely to track steps with smartphones than wearable devices
#
# Topic #4:
# food dining dp restaurant editor meal eat option truck bon eating coffee bar morning sleep drink dinner news book paper
# 2443
# Chef reflects on switch to Bon Appetit
# 14420
# Top Chef to open U. City restaurant next week
# 22007
# Students weigh in on life without the meal plan
# 19811
# Penn students with special diets share their food secrets
# 22850
# First chance of snow coming up this weekend
# 5893
# 1920 Commons revamps dining options
# 16471
# Green Eggs Café, a popular brunch spot, now serving drinks
# 21922
# 10 things to do if you get sexiled
# 17282
# Jake’s Sandwich Board opens today
# 27456
# 7 go-to snacks you need to keep in your room
#
# Topic #5:
# culture word black sasupennedu appears believe conversation self studying white talk matter sex medium simply society opinion relationship parent value
# 15807
# Guest column by Hector Kilgoe and Ana Schwartz | Breaking-Up with the Idea of the Friend
# 18425
# Oscar A. Rudenstam | Reconsidering religion in society, part II
# 19125
# Gina Elia | Silence is golden
# 16856
# Katiera Sordjan | Too much activism?
# 21552
# Isabel Kim | "You're pretty white"
# 14190
# Letter to the Editor | To the defacers of Penn Secular Society’s poster…
# 21835
# Amy Chan | If God is love, what is homosexuality?
# 17111
# Katiera Sordjan | Don't be colorblind
# 23397
# Guest Column by Sriram Sridharan | Deal with it: A statement on safe spaces
# 12689
# Your Voice | A Wall for Freedom
#
# Topic #6:
# ua committee chair meeting discussion club assembly body council lgbt representative gender asian speaker initiative sac cultural government diversity china
# 18511
# Undergraduate Assembly names new leaders in internal election
# 28190
# UA is optimistic about transparency efforts despite low attendance at open forum
# 16793
# Undergraduate Assembly secretary Natalie Hernandez resigns
# 9567
# Stephen Ahn
# 12403
# Joyce Kim
# 12380
# Jake Meiner
# 16346
# David Rubies Rivas
# 9583
# Abe Sutton
# 9573
# Abe Sutton
# 16388
# Rona Ji
#
# Topic #7:
# match tournament yale cornell brown soccer opponent dartmouth ranked columbia scored squad sunday title championship lost wrestling scoring double ncaa
# 20794
# Penn wrestling starts strong at NCAA Championships
# 20817
# Penn Wrestling's Casey Kent earns All-American honors
# 23340
# Penn wrestling hits the road for brutal conference triple-header
# 1535
# W. Lax | Penn comes close to the unthinkable
# 28392
# Penn wrestling falls to Princeton, bounces back with pair of nonconference wins
# 10391
# Penn women's soccer takes two at Rhodes Field
# 27128
# Penn women's soccer bounces back to sweep rainy weekend slate
# 20800
# Casey Kent earns All-American status at NCAA Wrestling Championships
# 21335
# Penn women's lacrosse falls to Cornell in Ivy title game as Corcoran sets conference assists record
# 9441
# Ortenzio wins 133-pound title at EIWA Championships
#
# Topic #8:
# election trump candidate republican vote political campaign voter obama democratic democrat presidential party biden clinton politics voting donald primary race
# 30748
# After Super Tuesday, Penn for Biden and Penn for Bernie prepare for lengthy primary battle
# 21263
# How the Pennsylvania primary works
# 29931
# In Tuesday's election, Penn student turnout increased five-fold from the last mayoral race
# 22228
# How a Wharton graduate's independent presidential bid could win Utah and upend the race
# 31345
# Penn Dems president secures delegate slot to represent Biden at Democratic National Convention
# 28557
# The Democratic primary is getting crowded. Here's how Penn Dems decides who to endorse.
# 7787
# Pennsylvania Republicans propose controversial changes to presidential voting system
# 28686
# Pa. congressman and Penn grad Conor Lamb on why Joe Biden stands out for the 2020 race
# 5315
# Republicans win big in Pennsylvania
# 5295
# Michelle Obama rallies crowd of 3,500 at Wynn Commons
#
# Topic #9:
# fraternity greek sorority chapter fling alcohol party concert spec protest alpha phi rush sigma council police drinking protester delta recruitment
# 10450
# Alpha Sigma Phi comes back to Penn
# 18790
# NEW STUDENT ISSUE: So you want to go Greek?
# 978
# Senior class will make 'Final Toast' on Hey Day
# 6146
# Skulls suspended after fatal fall
# 4137
# Fiji receives official charter
# 30604
# SPEC returns Spring Fling to two-day format with concert on Friday night
# 6492
# Throwback: March 3
# 21287
# SPEC-TRUM cancels spring concert following two artist cancellations
# 17331
# Protesters demand justice after grand jury decisions
# 6575
# Lupe Fiasco to headline Fling concert
#
# Topic #10:
# engineering company online technology degree learning teaching dean summer computer art professional mba internship teach skill industry writing interested lecture
# 11685
# Some students pursue alternatives to on-campus recruiting
# 12274
# Economics class to open globally through Coursera
# 13236
# Two Wharton professors partner on new social enterprise e-book
# 30035
# New digital humanities class aims to bring more humanities students to computation
# 9421
# Large courses make changes to engage students
# 13903
# Penn competition adds global perspective
# 16924
# Wharton student leaders suggest improvements for curriculum
# 18261
# Students look to consulting for diverse learning opportunities
# 19297
# Y-Prize competition kicked off Monday
# 29908
# Award-winning Marketing professor Cait Lamberton on why she chose to teach at Wharton
#
# Topic #11:
# west space store company facility local construction million location market cost park septum district renovation resident neighborhood price site estate
# 6019
# SEPTA to implement electronic fare system
# 5416
# New South Street Bridge a lifeline for local businesses
# 23474
# Put away your tokens — SEPTA Key cards are soon to be more widespread
# 3751
# Editorial | Make fare changes
# 13346
# FroGro to see lower prices, greater variety
# 5431
# Editorial | Driving traffic
# 7213
# Fresh Grocer wine machine may soon offer hard liquor
# 3799
# Editorial | Bridge plans not going South
# 12843
# SEPTA fare may increase in July
# 3731
# SEPTA proposes new fare hikes
#
# Topic #12:
# law government tax israel federal court worker legal act union million immigrant employee immigration political nation justice israeli administration palestinian
# 13691
# ICYMI: Pa. same-sex marriage lawsuits
# 24407
# What Trump's reversal on DACA means for undocumented students at Penn
# 15776
# Plaintiffs in Pa. same-sex lawsuit ask court for decision before trial
# 22965
# Portland dean resigns over 'sanctuary campus' label
# 20906
# UC system releases statement condemning anti-Semitism
# 22847
# Harvard President says 'sanctuary' label would offer 'false and misleading assurance'
# 22844
# Sanctuary campuses, including Penn, targeted by U.S. congressman
# 1008
# Nutter's budget proposal criticized
# 20639
# Penn files brief in opposition to graduate student labor unions
# 19560
# Graduate students at private schools may get collective bargaining
#
# Topic #13:
# basketball guard allen palestra mclaughlin donahue rebound shooting court tournament scoring rosen cornell offensive brown yale offense double columbia jerome
# 14476
# Top 10 Penn-Villanova basketball games of all time
# 20514
# 54 first-half points help Penn women's basketball blow by Yale, 77-59
# 14204
# Top 10 Penn-Temple basketball games of all time
# 20061
# Penn men's basketball falls in overtime to Drexel, 53-52
# 25911
# Clutch play down the stretch among takeaways from Penn's overtime win over Brown
# 3045
# Quakers Retrieve initial victory
# 23482
# Betley explodes on offense as Penn men's basketball cruises to third straight Ivy win
# 18219
# Penn women's hoops falls in WNIT Second Round
# 20802
# Penn women's basketball falls in first round of NCAA Tournament, 65-53
# 27763
# Margolis | Penn men's basketball will overcome the loss of Ryan Betley
#
# Topic #14:
# sport athlete football athletics guy athletic coaching teammate captain assistant title lacrosse injury kid ncaa murphy championship recruiting carr young
# 26354
# After injuries ended his football career, junior Alex Andersen walks on to Penn men's lacrosse
# 13404
# Stuecheli ready to lead Penn volleyball past Yale
# 28398
# Transfers Sanford and Gallagher look to make a major impact for Penn men's lacrosse
# 4091
# New coach Dave Wood set to spark fire under linebackers
# 4088
# Wood set to spark fire under linebackers
# 19227
# Back from injury, senior captain DeSilva ready to lead Penn volleyball
# 26719
# Two months after departure of Schumacher-Cawley, Penn volleyball names new head coach
# 26358
# From average to All-American: Penn men's lacrosse's Connor Keating continues to adapt his game
# 23571
# Penn volleyball hires Katie Schumacher-Cawley as new head coach
# 3971
# Volleyball welcomes new class
#
# Topic #15:
# financial admission aid application increase applicant rate cost international institution grant abroad money higher tuition furda fund income dean funding
# 12536
# Undergraduate tuition rises by 3.9 percent again
# 8869
# Financial aid proves key factor for middle-income applicants
# 26116
# How Penn's $75 application fee stacks up across the Ivy League
# 30855
# Penn admits 8.07% of applicants to the Class of 2024, a slight uptick from last year
# 8983
# Like Penn, other Ivies see fall in applicant numbers
# 9748
# Admit rate holds steady at 12.3 percent
# 15198
# Financial Aid Differs Across the Ivies
# 17426
# Early decision admission rate drops by 1.3 percentage points
# 885
# Mid-year aid requests see no 'sharp rise' | Interactive graphic
# 26501
# How Penn's tuition hike stacks up across the Ivy League
#
# Topic #16:
# inning hit baseball pitcher series king cole pitching softball base yurkow golf average single pitch division doubleheader bat hitting plate
# 15838
# Penn baseball splits with Columbia, heading to one-game playoff
# 18686
# Penn baseball heading to one-game playoff
# 21077
# Late-inning runs responsible for weekend split for Penn baseball at Dartmouth, Harvard
# 24142
# Penn baseball falls in Liberty Bell Classic championship after losing lead late to La Salle
# 18345
# Penn baseball survives wild weekend, winning three of four
# 28675
# Solid pitching leads the way in Penn softball's sweep of La Salle
# 15666
# Penn baseball takes three of four from Cornell
# 26850
# Penn baseball eliminated from Ivy title contention after taking one of three at Columbia
# 21028
# Penn baseball holds off late rally from Lafayette in 6-5 win
# 28712
# Despite hot bats, Penn baseball falls to Harvard in three-game series
#
# Topic #17:
# black gutmann climate environmental energy green sustainability movement trustee amy fossil statement african administration law occupy white protest water fuel
# 29215
# Penn Law Dean Ted Ruger on Amy Wax’s remarks: 'bigoted' at best, 'racist' at worst
# 26361
# President of Black Law Student Association on Wax's removal: 'there's more work to be done'
# 20738
# Harvard Law to remove seal with slaveholding roots
# 29549
# Weekly Fossil Free Penn sit-ins demand a public town hall on University's investments
# 26945
# Penn unveils new findings on history with slavery: over 75 former trustees owned slaves
# 16018
# Trustees opt against tobacco divestment
# 20935
# Guest Column by Zach Rissman | Uncovering bias in Penn's important process
# 17802
# Protesters stage sit-in at Harvard
# 23912
# Harvard students block doorways to protest fossil fuels while Fossil Free Penn sits in College Hall
# 26292
# After 'disparaging' comments on black students, Amy Wax barred from teaching first-year course
#
# Topic #18:
# sexual police safety assault violence rush dp crime officer housing incident report gun security reported victim resident sent division investigation
# 1559
# Nine cases of swine flu confirmed in Philadelphia
# 13890
# Former lecturer's trial is postponed
# 5482
# Electrical problems spur early morning fire alarm in Harnwell
# 19356
# UPenn Advisory warns of threat of violence to unspecified Philadelphia university
# 1156
# News Brief | Student charged with terrorist threats
# 932
# Student with meningitis released from hospital
# 17030
# Princeton fails to provide sexual misconduct policies, violates Title IX
# 3040
# SHS announces possible final H1N1 vaccine clinic
# 14009
# Penn Police defend handling of Mad Mex incident
# 24472
# Two Penn students stand trial on charges of assaulting a Wharton sophomore
#
# Topic #19:
# art museum music club love film library book audience artist water song video movie dance girl trip walk band tour
# 11913
# Penn grad blends genres in upcoming zombie movie
# 1128
# Students light up the Rotunda
# 6028
# Mask and Wig's 'Volcanic Corruption' draws eruptive laughter
# 16756
# Mask and Wig brings digital media into its fall show
# 12775
# Art and music project features work of disabled artists
# 15970
# Filling silent films with song
# 13651
# All ‘Roads’ lead to ICA
# 2130
# Alumna shares discovery of her grandfather, architect Louis Kahn
# 19719
# Going behind the scenes of Pixar's 'The Good Dinosaur'
# 14118
# Organist holds masterclass on improvising film scores

# %%
import joblib

# %%
filename = 'lda_model20.sav'
joblib.dump(lda, filename)
# Out:
# ['lda_model20.sav']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vect = TfidfVectorizer(stop_words='english',max_df=0.7, min_df=20)
tfidf = vect.fit_transform(sample_data['content_p'])

# %%
print(vect.get_feature_names())
# Out:
# ['aa', 'aagenes', 'aaron', 'aau', 'aback', 'abandon', 'abandoned', 'abandoning', 'abbey', 'abby', 'abc', 'abdel', 'abe', 'abid', 'abide', 'abiding', 'abigail', 'ability', 'abington', 'able', 'abnormal', 'aboard', 'abolish', 'abolished', 'abolishing', 'abolition', 'abortion', 'abou', 'abound', 'abraham', 'abrams', 'abramson', 'abreu', 'abroad', 'abrupt', 'abruptly', 'absence', 'absent', 'absentee', 'absolute', 'absolutely', 'absorb', 'absorbed', 'absorbing', 'abstain', 'abstinence', 'abstract', 'absurd', 'absurdity', 'abu', 'abundance', 'abundant', 'abundantly', 'abuse', 'abused', 'abusing', 'abusive', 'abuzz', 'abysmal', 'ac', 'aca', 'academia', 'academic', 'academically', 'academy', 'acc', 'accelerate', 'accelerated', 'accelerating', 'accelerator', 'accent', 'accept', 'acceptable', 'acceptance', 'accepted', 'accepting', 'accepts', 'access', 'accessed', 'accessibility', 'accessible', 'accessing', 'accessory', 'accident', 'accidental', 'accidentally', 'acclaim', 'acclaimed', 'acclimated', 'accolade', 'accommodate', 'accommodated', 'accommodating', 'accommodation', 'accompanied', 'accompanies', 'accompany', 'accompanying', 'accomplish', 'accomplished', 'accomplishing', 'accomplishment', 'accord', 'accordance', 'according', 'accordingly', 'account', 'accountability', 'accountable', 'accountant', 'accounted', 'accounting', 'accreditation', 'accredited', 'accrued', 'accumulate', 'accumulated', 'accumulating', 'accumulation', 'accuracy', 'accurate', 'accurately', 'accusation', 'accuse', 'accused', 'accuser', 'accuses', 'accusing', 'accustomed', 'ace', 'ache', 'achievable', 'achieve', 'achieved', 'achievement', 'achieving', 'achilles', 'acid', 'acknowledge', 'acknowledged', 'acknowledgement', 'acknowledges', 'acknowledging', 'acknowledgment', 'acl', 'aclu', 'acme', 'acoustic', 'acquaintance', 'acquainted', 'acquire', 'acquired', 'acquiring', 'acquisition', 'acquitted', 'acre', 'acrobatic', 'acronym', 'act', 'acted', 'acting', 'action', 'actionable', 'actions', 'activate', 'activated', 'active', 'actively', 'activism', 'activist', 'activities', 'activity', 'actor', 'actress', 'actual', 'actually', 'acumen', 'acute', 'acutely', 'ad', 'adage', 'adam', 'adamant', 'adams', 'adapt', 'adaptable', 'adaptation', 'adapted', 'adapting', 'add', 'addams', 'added', 'addict', 'addicted', 'addiction', 'addictive', 'adding', 'addition', 'additional', 'additionally', 'address', 'addressed', 'addressing', 'adelman', 'adept', 'adequate', 'adequately', 'adhere', 'adherence', 'adhering', 'adjacent', 'adjunct', 'adjust', 'adjusted', 'adjusting', 'adjustment', 'adkins', 'adler', 'administer', 'administered', 'administering', 'administers', 'administration', 'administrative', 'administrator', 'administrators', 'admirable', 'admirably', 'admiration', 'admire', 'admired', 'admires', 'admission', 'admissions', 'admit', 'admits', 'admittance', 'admitted', 'admittedly', 'admitting', 'adobe', 'adolescence', 'adolescent', 'adopt', 'adopted', 'adopting', 'adoption', 'adorned', 'adrenaline', 'adrian', 'adrienne', 'adult', 'adulthood', 'advance', 'advanced', 'advancement', 'advancing', 'advantage', 'advantageous', 'advent', 'adventure', 'adventurous', 'adversary', 'adverse', 'adversely', 'adversity', 'advertise', 'advertised', 'advertisement', 'advertiser', 'advertises', 'advertising', 'advice', 'advise', 'advised', 'advisee', 'adviser', 'advises', 'advising', 'advisor', 'advisory', 'advocacy', 'advocate', 'advocated', 'advocating', 'aerial', 'aesthetic', 'aesthetically', 'afaf', 'afar', 'affair', 'affairs', 'affect', 'affected', 'affecting', 'affection', 'affectionately', 'affidavit', 'affiliate', 'affiliated', 'affiliation', 'affinity', 'affirm', 'affirmation', 'affirmative', 'affirmed', 'affirming', 'affirms', 'afflicted', 'affluent', 'afford', 'affordability', 'affordable', 'afforded', 'affording', 'affords', 'afghanistan', 'afloat', 'aforementioned', 'afraid', 'africa', 'african', 'africana', 'afro', 'aftermath', 'afternoon', 'afterthought', 'afterward', 'agarwal ...

# %%
from sklearn.decomposition import NMF
model = NMF(n_components=20, init='random', random_state=0)
W = model.fit_transform(tfidf)
H = model.components_

# %%
print(tfidf.shape)
# Out:
# (31477, 16092)

# %% [markdown]
# # NMF (using TFIDF) Topics and Articles

# %%
number_topics = 20
number_words = 20
number_documents = 10
print_topics(model, vect, number_words, number_documents,150,tfidf)
# Out:
# Topic #0:
# point game quaker guard basketball allen half mclaughlin minute rebound donahue shot shooting second red play blue lead team big
# 25690
# AJ Brodeur and Ryan Betley lead the Red and Blue to weekend sweep
# 8714
# Penn basketball heads into break with win over Marist
# 14211
# Penn women's basketball drops season opener to St. Francis (NY)
# 12170
# Freshman Tony Hicks shines in Penn basketball's takedown of Big Red
# 23378
# Matt Howard turns in marquee effort to guide Quakers to victory against Columbia
# 20432
# Penn women's basketball stays perfect in Ivy play
# 8850
# Quakers knock off St. Joseph's in Big 5 Finale
# 26180
# In a thrilling back-and-forth affair, Penn men's basketball tops Harvard, 74-71
# 11986
# Late Yale run dooms Penn basketball, 68-59
# 14733
# Penn basketball rides offensive outburst to easy win over NJIT, 89-74
#
# Topic #1:
# yard touchdown football quarterback game bagnoli quaker receiver offense ragone quarter defense running priore field play drive rushing defensive torgersen
# 4950
# Ragone leads Penn past Dartmouth in overtime
# 24950
# Penn football falls to Columbia in overtime, 34-31
# 10932
# Tony | Penn defense falters against inferior Lions
# 10741
# Penn football holds off Big Green in Ivy opener
# 7903
# Penn football runs through Fordham with five TDs
# 19024
# Taking a look at Penn football's nonconference matchups
# 25369
# Last-second goal-line stand boosts Penn football to wild win over Cornell in season finale
# 21554
# Retelling the narrative arc of Penn football's 2015 championship
# 13978
# Penn football defeats Columbia in ugly affair, 21-7
# 11110
# Defensive stops keep Penn football alive
#
# Topic #2:
# team woman meet men relay championship event season race finish second meter track finished quaker competition place athlete freshman invitational
# 26845
# With Olympic legends in attendance, Quakers shine in 124th edition of Penn Relays
# 3728
# Quakers finish indoor track season with championship meets
# 15018
# Penn swimming puts chill into southern opponents
# 15187
# Penn track and field struggles at Heptagonals, finishing seventh
# 11247
# Penn swimming too much to handle for UConn
# 14534
# 'Fast Times before Finals' yields positive results for Penn track
# 27338
# Penn cross country showcases depth and improvement at two meets
# 25775
# Penn swimming gets back on track with dominant wins over Army
# 14138
# Penn cross country content with finish at "Heps"
# 15420
# Penn track soaks up the sun in home opener
#
# Topic #3:
# game goal quaker minute red inning blue half run second shot field team play win ball season defense scored score
# 29399
# Penn field hockey remains winless on season after pair of tight losses
# 27368
# Working overtime: All but one game has needed extra time for Penn men's soccer this year
# 24696
# Back-and-forth weekend sees Penn field hockey win one, lose one in tight games
# 26776
# Penn women's lacrosse makes history with offensive explosion in win over Harvard
# 29537
# Penn field hockey records first two wins of season against Cornell and Temple
# 10436
# Penn field hockey splits weekend, off to best start since 1997
# 13899
# Penn field hockey blows out UMass-Lowell for third straight win
# 24013
# Penn women's lacrosse dominates Dartmouth in 17-6 blowout to stay in Ivy title race
# 30638
# No. 8 Penn men's lacrosse defeats No. 10 Duke in neutral-site showdown
# 12990
# Big Green fall to Penn men's lacrosse in Senior Day blowout
#
# Topic #4:
# match quaker team win set squash weekend tennis victory red wyant blue double season single wrestling carr ranked loss point
# 9992
# Penn women's tennis scores huge upset Saturday
# 23611
# Penn tennis squads both split weekend doubleheaders
# 12991
# Penn men's tennis defeated by two ranked foes
# 26648
# Both Penn tennis teams edge Cornell after losing against Columbia
# 23761
# Penn women's tennis sweeps singles play en route to a 6-1 victory over St. John's
# 9433
# Tennis shows great potential but drops several close matches
# 6383
# Quakers cruise in Navy sweep
# 11904
# Penn men's tennis breaks even in season opening doubleheader
# 12756
# Penn men's tennis seeks first Ivy League victory on road trip
# 28846
# Penn women's tennis wins first Ivy match at Dartmouth, men fall to 0-3
#
# Topic #5:
# wharton course class program professor school science research student engineering faculty business study graduate art department undergraduate technology education online
# 29143
# Wharton establishes new online courses at the intersection of finance and technology
# 30110
# How a seven-week Wharton course brings the study of cryptocurrency to the classroom
# 25691
# The 'fintech' trend has caught on at Wharton, but many students want more
# 14482
# New website allows students to suggest Wharton courses
# 21243
# Wharton rolls out major curriculum redesign, with four-year MGMT 100 and more focus on ethics
# 24788
# Penn students take pride in their home schools, but many take half their classes in the College
# 6667
# Wharton plans new writing curriculum
# 20338
# New computer science class dreamed up by enthusiastic students
# 24373
# How to organize your course cart — Penn seniors speak from experience
# 24386
# Four years, two degrees — here's what life is like for students in Penn's dual degree programs
#
# Topic #6:
# student campus group college community service event university resource semester program international undergraduate house issue graduate housing mental cap support
# 30899
# Editorial | With Quaker Days canceled, here are 10 things to consider about Penn.
# 26563
# Guest Statement by Samara Wyant and Max Grove | Mental health, cost, campus, community: Samara and Max for UA
# 30791
# Live updates —  Penn's response to coronavirus outbreak
# 23783
# Guest Column by Karen Hamilton | Penn and diversity — another view
# 5356
# Wiki-Pedia | Bridging the gap with Thanksgiving
# 21206
# Following in Brown, Penn's first-generation students hope for their own center
# 31295
# Penn will conduct fall 2020 on campus with hybrid of online and in-person instruction
# 19940
# Guest Column by the Hamlett-Reed Mental Health Initiative | Thank you, Penn
# 14906
# How other colleges  respond to  death
# 28755
# Grad students demand more resources for cultural centers at University Council Open Forum
#
# Topic #7:
# sexual assault violence woman rape university campus policy victim harassment gender sex misconduct issue survey men report faculty prevention survivor
# 1133
# Sarah Cantin | Moving beyond sex-violence stereotypes
# 21062
# Students Take Back the Night with rally against sexual assault
# 15943
# Penn to revamp NSO sexual violence training
# 20833
# University will add more questions about sexual violence to student surveys
# 26788
# Penn students: Does a ban on faculty-student sexual relations address issues on our campus?
# 16146
# NSO sexual violence session sees changes
# 19892
# Three changes coming to campus following the AAU sexual assault survey
# 21849
# One year after the results of the AAU sexual assault survey, a look at what's changed
# 23242
# How will sexual assault policy at Penn change under Trump?
# 10318
# University revises sexual violence policy
#
# Topic #8:
# police rush safety dp officer crime public incident street security alert robbery philadelphia division department maureen theft according black patrol
# 17059
# Busting barriers, Penn's top cop celebrates 20 years
# 6479
# Bullet shells found after 41st, Pine gunfire
# 19726
# Penn Police receives high praise from community, administrators at accreditation hearing
# 11967
# Drexel police serve as 'extra layer' of security at Penn
# 581
# DPS responds to recent police fatality
# 17660
# 2014: The year in crime
#
# 21791
# Penn Police officer, Phila. sergeant among six people shot by gunman blocks from campus
# 18085
# Penn Police join procession for fallen officer Robert Wilson III
# 18703
# Penn Police sensitivity trainings aim to combat excessive use of force
# 8817
# DPS ranks first in safety and security in higher education
#
# Topic #9:
# philadelphia city building food street house new project community restaurant center west space store university service dining th campus resident
# 21930
# Why Philadelphia is a city that sleeps...for now
# 7774
# New report deems University City safe, vibrant
# 26016
# Why there are fewer green buildings on campus than downtown
# 21114
# Better together: Penn and Philly create mutually beneficial relationship
# 26201
# Penn opts out of West Philly green building initiative
# 6783
# Philadelphia sees population jump
# 26252
# Philadelphia is named one of the '10 coolest U.S. cities to visit' in recent ranking
# 3548
# Grad students embrace variety of city's neighborhoods
# 10564
# Joyce Kim | It’s Always Sunny In West Philadelphia
# 12880
# City planners to present draft of University Southwest District Plan
#
# Topic #10:
# admission school percent university applicant application furda aid financial year decision college increase student rate education early tuition number ranking
# 17426
# Early decision admission rate drops by 1.3 percentage points
# 5902
# Total applications hit record highs across schools
# 2898
# Penn sees rise in ED applications
# 8983
# Like Penn, other Ivies see fall in applicant numbers
# 6773
# Admissions rate drops to 12.3 percent
# 17015
# Penn ED apps increase by 5 percent to all-time high
# 9748
# Admit rate holds steady at 12.3 percent
# 16900
# Coming soon: The early decision deadline
# 3991
# Admit rate falls to 14.2 percent
# 14271
# Penn Admissions sees new high in ED applicants
#
# Topic #11:
# reported unaffiliated suspect block street male unknown theft arrested st old removed female walnut located unattended th university vehicle man
# 6982
# Crime log: March 26 - April 7
# 4477
# Crime Log: May 21-27
# 7558
# Crime log: Sept. 2-8
# 3396
# Crime Log: Jan. 30-Feb. 5
# 4079
# Crime log: March 27-April 2
# 1546
# Crime Log | Interactive map
# 1963
# Crime log: Sept. 11-17
# 2592
# Crime Log
# 9091
# Crime Log | Jan. 27 - Feb. 2
# 3725
# Crime Log: Feb. 27-March 5
#
# Topic #12:
# election vote voter candidate republican democrat pennsylvania democratic political state voting party campaign obama turnout poll law clinton race presidential
# 29833
# Hadriana Lowenkron | Vote in your local elections. It can make a difference.
# 24038
# GOP and Green Party contest new Dem representative in North Philly with claims of illegal electioneering
# 27026
# Spencer Swanson | Don't boo. Vote.
# 2113
# Low interest for Nov. election
# 22054
# Why all those Clinton volunteers have been trying to switch your voter registration to Pennsylvania
# 7768
# Emma Ellman-Golan | A less democratic distribution
# 29931
# In Tuesday's election, Penn student turnout increased five-fold from the last mayoral race
# 17079
# Student apathy caused low voter turnout, local leaders say
# 18712
# Pennsylvania to play role in 2016 presidential election
# 11273
# Despite predictions, youth voter turnout approached or surpassed 2008
#
# Topic #13:
# fraternity greek sorority chapter house member event alpha phi organization sigma council recruitment campus panhellenic ifc delta life president rush
# 216
# It's all Greek to me | Going Greek across the Ivies | Interactive feature
# 7435
# Greek Life | The low-down on Penn Greek life
# 1707
# GREEK LIFE | Balancing parties with community service and academics
# 18790
# NEW STUDENT ISSUE: So you want to go Greek?
# 174
# It's all Greek to me | New pledge classes join 160-year history | Interactive timeline
# 29266
# Thinking of rushing? Here's what you need to know about Greek life at Penn
# 7579
# Greeks to recruit upperclassmen this fall
# 16779
# Bills and barriers: Greek life, beyond the sticker price
# 14691
# Guest Column by Scott Reikofski | Commending our chapters
# 24497
# Friendships, financial burdens and 'heteronormative masculinity': students reflect on going Greek
#
# Topic #14:
# health patient medicine mental care research medical hospital cancer center study disease nursing cap treatment researcher university service clinical drug
# 22203
# Penn received $3.7 million to build a new center for mental health research
# 23782
# Princeton HealthCare's merge with Penn Medicine represents positive national shifts in the industry, experts say
# 16674
# Guest column by Penn Democrats | Health care sanity
# 25164
# A year after Penn, this Nursing graduate has launched a startup to treat patients in their homes
# 2202
# Penn Med students prepared for business side of health care
# 15119
# When One Peer Goes a Long Way
# 24972
# Given the recent threats to Obamacare, do Penn students need to worry about access to mental health care?
# 24585
# Penn researchers found a way to improve treatment and lower costs for uninsured patients
# 25139
# How Penn's mental health efforts have evolved in the past 70 years
# 15083
# Researching mental health at Penn
#
# Topic #15:
# ivy league team season princeton game harvard tournament year conference player title yale win cornell coach quaker dartmouth brown columbia
# 27919
# A Decade in Ivy Sports: Which rivalries are the most competitive?
# 30750
# Ivy League men's basketball power rankings: Week 7
# 29870
# Harvard is the favorite, but what can we expect from the other Ivy men's teams?
# 2505
# Ivy title races fall-ing into place for Penn
# 27031
# Which Ivy League teams have had the most success over the past decade?
# 21270
# Tydings | Taking a look at the planned Ivy League basketball tournament
# 29871
# Princeton is favored to repeat again, but what about the other women's teams?
# 6641
# Seifter | Surviving the streak
# 23690
# Jacobson | Ivy Tournament was fun — but was it best for the league?
# 20219
# Steele | 14 games are good enough
#
# Topic #16:
# ua representative assembly body undergraduate committee board member budget president election sac meeting group class vice elected government nec vote
# 28979
# The UA’s new executive board plans to tackle efficiency and transparency next year
# 16896
# A name change for the Class Boards
# 9895
# Optimism highlights internal Undergraduate Assembly elections
# 2543
# Proposal draft details UA reform
# 13698
# Retention rate raises questions for the UA
# 4977
# UA recap: New representatives join the body at weekly meeting
# 20888
# UA presidential hopefuls discuss experience, visibility in first of three debates
# 18242
# Candidates for College Representative
# 6238
# UA debates possible campus smoking ban
# 15244
# In wake of impeachment petition, UA presidential hopefuls make preparations
#
# Topic #17:
# trump president biden donald gutmann university clinton american political republican wharton immigration united state speech israel presidential country protest policy
# 22487
# A roadmap of Trump's candidacy and its effects at Penn
# 19118
# What we actually know about Donald Trump's ongoing relationship with Penn
# 18916
# Rising in polls and troubling the establishment, Donald Trump moves forward
# 22656
# Editorial | Making change in Trump's America
# 25581
# A look back at all of The Daily Pennsylvanian's Trump reporting in 2017
# 21380
# Louis Capozzi | Another brick in the wall
# 21538
# Trump formally accepts GOP nomination
# 20094
# Penn for Trump dumps Trump
# 20675
# News Analysis | From Penn to South Carolina, young Trump supporters are few and far between
# 22410
# 12 'firsts' Donald Trump would accomplish if he wins
#
# Topic #18:
# sas edu upenn email college claar bclaar scarsdale ben address claudli bradhong morristown clara skhan freshman santa brad claudia li
# 20954
# Ben Claar | Ivy League
# 21037
# Ben Claar | My friend sleep
# 20581
# Ben Claar | Micro management
# 21200
# Ben Claar | The fling experience
# 20235
# Ben Claar | Bob the engineer
# 20157
# Ben Claar | Great advisors of the world
# 20860
# Ben Claar | This is real life
# 20772
# Ben Claar | Trumpie Comics
# 20319
# Ben Claar | Lego Allegro
# 20677
# Ben Claar | Damn Daniel
#
# Topic #19:
# people like time friend life year thing think know college really make want day feel way experience class say love
# 29107
# Senior Column by David Figurelli | A reflection
# 13608
# Rachel del Valle | Freshman friends are not forever
# 18783
# Senior column by Taylor Culliver | Stay the motherf**king course
# 29255
# James Morrison | Don’t leave your high school friends behind in college
# 10135
# Rachel del Valle | Picking up London's call
# 25130
# DiGregorio | How I cope with mental health issues as a student-athlete
# 949
# Talking Points | Catching up with Doug Glanville
# 18773
# Gianni Mascioli | Moments of courage
# 26870
# Senior Column by Alessandro van den Brink | You can take the boy out of the DP, but you can’t take the DP out of the boy
# 22703
# Emily Hoeven |It's complicated
